# %%
data = spark.read.parquet("/mnt/gmps/Event0c")
data.head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: []</div>

# %%
mini_frame['time'] = pd.to_datetime(df['datetime'], unit='s')
mini_frame['epoch'] = pd.to_numeric(df['epoch'])
mini_frame['SCmicrosec'] = df['SCmicrosec']

# %%
#import databricks.koalas as ks
import pandas as pd
import numpy as np
import glob
import h5py
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
directory = '/dbfs/mnt/gmps/eventdata'
relevant_files = glob.glob1(str(directory),"MLEventData*.h5") #MLParamData*.h5

# %%
relevant_files
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: [&#39;MLEventData_1561738277.7050312_From_EventC_2019-06-27 00:00:00_to_2019-06-28 00:00:00.h5&#39;,
#  &#39;MLEventData_1561740968.162676_From_EventC_2019-06-26 00:00:00_to_2019-06-27 00:00:00.h5&#39;,
#  &#39;MLEventData_1561742761.6272554_From_EventC_2019-06-25 00:00:00_to_2019-06-26 00:00:00.h5&#39;,
#  &#39;MLEventData_1561744543.4673789_From_EventC_2019-06-24 00:00:00_to_2019-06-25 00:00:00.h5&#39;,
#  &#39;MLEventData_1561746365.6698549_From_EventC_2019-06-23 00:00:00_to_2019-06-24 00:00:00.h5&#39;,
#  &#39;MLEventData_1561748314.7454574_From_EventC_2019-06-22 00:00:00_to_2019-06-23 00:00:00.h5&#39;,
#  &#39;MLEventData_1561753916.6400647_From_EventC_2019-06-21 00:00:00_to_2019-06-22 00:00:00.h5&#39;,
#  &#39;MLEventData_1561759732.2323198_From_EventC_2019-06-20 00:00:00_to_2019-06-21 00:00:00.h5&#39;,
#  &#39;MLEventData_1561765465.6224027_From_EventC_2019-06-19 00:00:00_to_2019-06-20 00:00:00.h5&#39;,
#  &#39;MLEventData_1561774687.0740492_From_EventC_2019-06-18 00:00:00_to_2019-06-19 00:00:00.h5&#39;,
#  &#39;MLEventData_1561774806.489091_From_EventC_2019-06-18 00:00:00_to_2019-06-19 00:00:00.h5&#39;,
#  &#39;MLEventData_1561780682.7402008_From_EventC_2019-06-17 00:00:00_to_2019-06-18 00:00:00.h5&#39;,
#  &#39;MLEventData_1561784252.7427125_From_EventC_2019-06-16 00:00:00_to_2019-06-17 00:00:00.h5&#39;,
#  &#39;MLEventData_1561784462.6653938_From_EventC_2019-06-28 00:00:00_to_2019-06-29 00:00:00.h5&#39;,
#  &#39;MLEventData_1561786098.0110128_From_EventC_2019-06-15 00:00:00_to_2019-06-16 00:00:00.h5&#39;,
#  &#39;MLEventData_1561787848.1316633_From_EventC_2019-06-14 00:00:00_to_2019-06-15 00:00:00.h5&#39;,
#  &#39;MLEventData_1561789601.1567118_From_EventC_2019-06-13 00:00:00_to_2019-06-14 00:00:00.h5&#39;,
#  &#39;MLEventData_1561791531.7517378_From_EventC_2019-06-12 00:00:00_to_2019-06-13 00:00:00.h5&#39;,
#  &#39;MLEventData_1561793312.7301278_From_EventC_2019-06-11 00:00:00_to_2019-06-12 00:00:00.h5&#39;,
#  &#39;MLEventData_1561795255.803328_From_EventC_2019-06-10 00:00:00_to_2019-06-11 00:00:00.h5&#39;,
#  &#39;MLEventData_1561796994.5220554_From_EventC_2019-06-09 00:00:00_to_2019-06-10 00:00:00.h5&#39;,
#  &#39;MLEventData_1561814624.0397882_From_EventC_2019-06-08 00:00:00_to_2019-06-09 00:00:00.h5&#39;,
#  &#39;MLEventData_1561824175.94154_From_EventC_2019-06-06 00:00:00_to_2019-06-07 00:00:00.h5&#39;,
#  &#39;MLEventData_1575273604.0985577_From_EventC_2019-12-01 00:00:00_to_2019-12-02 00:00:00.h5&#39;,
#  &#39;MLEventData_1575360002.723245_From_EventC_2019-12-02 00:00:00_to_2019-12-03 00:00:00.h5&#39;,
#  &#39;MLEventDat

# %%
f= h5py.File('/dbfs/mnt/gmps/'+str(relevant_files[1]), 'r')   
h5_keys = list(f.keys())
f.close()
print(h5_keys)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;Event00&#39;, &#39;Event02&#39;, &#39;Event07&#39;, &#39;Event0a&#39;, &#39;Event0c&#39;, &#39;Event0e&#39;, &#39;Event0f&#39;, &#39;Event10&#39;, &#39;Event11&#39;, &#39;Event12&#39;, &#39;Event13&#39;, &#39;Event17&#39;, &#39;Event18&#39;, &#39;Event1a&#39;, &#39;Event1b&#39;, &#39;Event1e&#39;, &#39;Event1f&#39;, &#39;Event20&#39;, &#39;Event22&#39;, &#39;Event25&#39;, &#39;Event26&#39;, &#39;Event2a&#39;, &#39;Event2c&#39;, &#39;Event2f&#39;, &#39;Event30&#39;, &#39;Event31&#39;, &#39;Event32&#39;, &#39;Event34&#39;, &#39;Event35&#39;, &#39;Event36&#39;, &#39;Event37&#39;, &#39;Event38&#39;, &#39;Event3a&#39;, &#39;Event3b&#39;, &#39;Event3c&#39;, &#39;Event3d&#39;, &#39;Event3f&#39;, &#39;Event4c&#39;, &#39;Event52&#39;, &#39;Event53&#39;, &#39;Event58&#39;, &#39;Event72&#39;, &#39;Event7a&#39;, &#39;Event7b&#39;, &#39;Event7c&#39;, &#39;Event7d&#39;, &#39;Event7e&#39;, &#39;Event7f&#39;, &#39;Event87&#39;, &#39;Event88&#39;, &#39;Event8f&#39;, &#39;Eventa1&#39;, &#39;Eventa2&#39;, &#39;Eventac&#39;, &#39;Eventb2&#39;, &#39;Eventb3&#39;, &#39;Eventb4&#39;, &#39;Eventb5&#39;, &#39;Eventba&#39;, &#39;Eventbe&#39;, &#39;Eventda&#39;, &#39;Eventde&#39;, &#39;Evente2&#39;, &#39;Evente3&#39;, &#39;Evente4&#39;, &#39;Evente6&#39;, &#39;Evente7&#39;, &#39;Evente8&#39;, &#39;Eventef&#39;, &#39;Eventf1&#39;, &#39;Eventf7&#39;, &#39;Eventfa&#39;]
# </div>

# %%
mf = pd.DataFrame()
mf['datetime'] = 0

df = pd.read_hdf('/dbfs/mnt/gmps/'+str(relevant_files[4]), 'Event0c')
mf.datetime = pd.to_datetime(df.datetime)

# %%
param_list = ['B:ACMNIG', 'B:ACMNPG', 'B:ACMXIG', 'B:ACMXPG', 'B:DCIG', 'B:DCPG', 'B:GMPS1V', 'B:GMPS2V', 'B:GMPS3V', 'B:GMPS4V', 'B:GMPSBT', 'B:GMPSFF', 'B:IMAXXG', 'B:IMAXXO', 'B:IMINER', 'B:IMINST', 'B:IMINXG', 'B:IMINXO', 'B:IPHSTC', 'B:NGMPS', 'B:PS1VGM', 'B:PS1VGP', 'B:PS2VGM', 'B:PS2VGP', 'B:PS3VGM', 'B:PS3VGP', 'B:PS4VGM', 'B:PS4VGP', 'B:VIMAX', 'B:VIMIN', 'B:VINHBT', 'B:VIPHAS', 'B_ACMNIG', 'B_ACMNPG', 'B_ACMXIG', 'B_ACMXPG', 'B_DCIG', 'B_DCPG', 'B_GMPSBT', 'B_GMPSFF', 'B_IMAXXG', 'B_IMAXXO', 'B_IMINST', 'B_IMINXG', 'B_IMINXO', 'B_IPHSTC', 'B_VIMAX', 'B_VIMIN', 'B_VINHBT', 'B_VIPHAS']

param_list2 = ['I:MXIB', 'I:IB', 'I:MDAT40', 'B:LINFRQ']
#removed B:IMINER since I already ran it
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.read_hdf('/dbfs/mnt/gmps/MLParamData_1560456433.9319363_From_MLrn_2019-06-12 23:59:59_to_2019-06-13 00:00:00.h5', 'B:ACMNIG')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
param_list = ['B:ACMNPG', 'B:ACMXIG', 'B:ACMXPG', 'B:DCIG', 'B:DCPG', 'B:GMPS1V', 'B:GMPS2V', 'B:GMPS3V', 'B:GMPS4V', 'B:GMPSBT', 'B:GMPSFF', 'B:IMAXXG', 'B:IMAXXO', 'B:IMINER', 'B:IMINST', 'B:IMINXG', 'B:IMINXO', 'B:IPHSTC', 'B:NGMPS', 'B:PS1VGM', 'B:PS1VGP', 'B:PS2VGM', 'B:PS2VGP', 'B:PS3VGM', 'B:PS3VGP', 'B:PS4VGM', 'B:PS4VGP', 'B:VIMAX', 'B:VIMIN', 'B:VINHBT', 'B:VIPHAS', 'B_ACMNIG', 'B_ACMNPG', 'B_ACMXIG', 'B_ACMXPG', 'B_DCIG', 'B_DCPG', 'B_GMPSBT', 'B_GMPSFF', 'B_IMAXXG', 'B_IMAXXO', 'B_IMINST', 'B_IMINXG', 'B_IMINXO', 'B_IPHSTC', 'B_VIMAX', 'B_VIMIN', 'B_VINHBT', 'B_VIPHAS', 'I:MXIB', 'I:IB', 'I:MDAT40', 'B:LINFRQ']

#already ran 'B:ACMNIG'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
param_list = ['Event0c']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
frame = pd.DataFrame()
frame['filename'] = ''
frame['time'] = 0
frame['SCmicrosec'] = 0
frame['UNIXepoch'] = 0

for file in relevant_files:
  print(file)
  #for param in param_list:

  mini_frame = pd.DataFrame()
  mini_frame['filename'] = ''
  mini_frame['UNIXepoch'] = 0
  mini_frame['time'] = 0
  mini_frame['SCmicrosec'] = 0

  try:
    df = pd.read_hdf('/dbfs/mnt/gmps/eventdata/'+str(file), 'Event0c')

    try:

      mini_frame['time'] = pd.to_datetime(df['datetime'])
      mini_frame['UNIXepoch'] = pd.to_numeric(df['epoch'])
      mini_frame['SCmicrosec'] = pd.to_numeric(df['SCmicrosec'])
      mini_frame['filename'] = str(file)

    except KeyError:

      mini_frame['time'] = pd.to_datetime(df['datetime'+str(key)])
      mini_frame['UNIXepoch'] = pd.to_numeric(df['epoch'+str(key)])
      mini_frame['SCmicrosec'] = pd.to_numeric(df['SCmicrosec'+str(key)])
      mini_frame['filename'] = str(file)

    frame = pd.concat([frame , mini_frame], axis=0, ignore_index=True)

  except (NameError, KeyError, OSError) as e:
    print("Event0c not in "+str(file))

frame.to_parquet('/dbfs/mnt/gmps/Event0c_complete', row_group_offsets=10000000, engine='fastparquet', compression= 'gzip')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ImportError</span>                               Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1013166560150505&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">     36</span>     print<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;Event0c not in &#34;</span><span class="ansi-blue-fg">+</span>str<span class="ansi-blue-fg">(</span>file<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     37</span>
# <span class="ansi-green-fg">---&gt; 38</span><span class="ansi-red-fg"> </span>frame<span class="ansi-blue-fg">.</span>to_parquet<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;/dbfs/mnt/gmps/Event0c_complete&#39;</span><span class="ansi-blue-fg">,</span> row_group_offsets<span class="ansi-blue-fg">=</span><span class="ansi-cyan-fg">10000000</span><span class="ansi-blue-fg">,</span> engine<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#39;fastparquet&#39;</span><span class="ansi-blue-fg">,</span> compression<span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#39;gzip&#39;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/util/_decorators.py</span> in <span class="ansi-cyan-fg">wrapper</span><span class="ansi-blue-fg">(*args, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    212</span>                 <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    213</span>                     kwargs<span class="ansi-blue-fg">[</span>new_arg_name<span class="ansi-blue-fg">]</span> <span class="ansi-blue-fg">=</span> new_arg_value
# <span class="ansi-green-fg">--&gt; 214</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">return</span> func<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">*</span>args<span class="ansi-blue-fg">,</span> <span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    215</span>
# <span class="ansi-green-intense-fg ansi-bold">    216</span>         <span class="ansi-green-fg">return</span> cast<span class="ansi-blue-fg">(</span>F<span class="ansi-blue-fg">,</span> wrapper<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/core/frame.py</span> in <span class="ansi-cyan-fg">to_parquet</span><span class="ansi-blue-fg">(self, path, engine, compression, index, partition_cols, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">   2114</span>             index<span class="ansi-blue-fg">=</span>index<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">   2115</span>             partition_cols<span class="ansi-blue-fg">=</span>partition_cols<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-fg">-&gt; 2116</span><span class="ansi-red-fg">             </span><span class="ansi-blue-fg">**</span>kwargs<span class="ansi-blue-fg">,</span>
# <span class="ansi-green-intense-fg ansi-bold">   2117</span>         )
# <span class="ansi-green-intense-fg ansi-bold">   2118</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/io/parquet.py</span> in <span class="ansi-cyan-fg">to_parquet</span><span class="ansi-blue-fg">(df, path, engine, compression, index, partition_cols, **kwargs)</span>
# <span class="ansi-green-intense-fg ansi-bold">    255</span>     <span class="ansi-green-fg">if</span> isinstance<span class="ansi-blue-fg">(</span>partition_cols<span class="ansi-blue-fg">,</span> str<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    256</span>         partition_cols <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">[</span>partition_cols<span class="ansi-blue-fg">]</span>
# <span class="ansi-green-fg">--&gt; 257</span><span class="ansi-red-fg">     </span>impl <span class="ansi-blue-fg">=</span> get_engine<span class="ansi-blue-fg">(</span>engine<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    258</span>     return impl.write(
# <span class="ansi-green-intense-fg ansi-bold">    259</span>         df<span class="ansi-blue-fg">,</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/io/parquet.py</span> in <span class="ansi-cyan-fg">get_engine</span><span class="ansi-blue-fg">(engine)</span>
# <span class="ansi-green-intense-fg ansi-bold">     40</span>         <span class="ansi-green-fg">return</span> PyArrowImpl<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     41</span>     <span class="ansi-green-fg">elif</span> engine <span class="ansi-blue-fg">==</span> <span class="ansi-blue-fg">&#34;fastparquet&#34;</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 42</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">return</span> FastParquetImpl<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     43</span>
# <span class="ansi-green-intense-fg ansi-bold">     44</span>     <span class="ansi-green-fg">raise</span> ValueError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;engine must be one of &#39;pyarrow&#39;, &#39;fastparquet&#39;&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/io/parquet.py</span> in <span class="ansi-cyan-fg">__init__</span><span class="ansi-blue-fg">(self)</span>
# <span class="ansi-green-intense-fg ansi-bold">    136</span>         <span class="ansi-red-fg"># we need to import on first use</span>
# <span class="ansi-green-intense-fg ansi-bold">    137</span>         fastparquet = import_optional_dependency(
# <span class="ansi-green-fg">--&gt; 138</span><span class="ansi-red-fg">             </span><span class="ansi-blue-fg">&#34;fastparquet&#34;</span><span class="ansi-blue-fg">,</span> extra<span class="ansi-blue-fg">=</span><span class="ansi-blue-fg">&#34;fastparquet is required for parquet support.&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">    139</span>         )
# <span class="ansi-green-intense-fg ansi-bold">    140</span>         self<span class="ansi-blue-fg">.</span>api <span class="ansi-blue-fg">=</span> fastparquet
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/pandas/compat/_optional.py</span> in <span class="ansi-cyan-fg">import_optional_dependency</span><span class="ansi-blue-fg">(name, extra, raise_on_missing, on_version)</span>
# <span class="ansi-green-intense-fg ansi-bold">     90</span>     <span class="ansi-green-fg">except</span> ImportError<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">     91</span>         <span class="ansi-green-fg">if</span> raise_on_missing<span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 92</span><span class="ansi-red-fg">             </span><span class="ansi-green-fg">raise</span> ImportError<span class="ansi-blue-fg">(</span>msg<span class="ansi-blue-fg">)</span> <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">     9

# %%
frame["time"] = pd.to_datetime(frame["time"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
frame.to_parquet('/dbfs/mnt/gmps/Event0c_complete', row_group_offsets=10000000, engine='fastparquet', compression= 'gzip')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
